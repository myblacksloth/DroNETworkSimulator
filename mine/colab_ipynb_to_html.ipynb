# %% [markdown]
# # ipyb to html converter
#
# ❌ ❌ ❌ i file gestiti da google colab, al termine del runtime, vengono eliminati (quindi persi)

# %% [markdown]
# ## how2use
#
# scaricare il file ipynb
#
# ![image.png](data:image/png;base64,...)
#
# caricare il file ipynb della directory di lavoro
#
# ![image.png](data:image/png;base64,...)
#
# eseguire lo script inserendo il nome del file ipynb
#
# aggiornare la lista dei file
#
# e al termine scaricare il file convertito

# %% [markdown]
# ## script

# %% [markdown]
# working directory

# %%
! pwd
# Out:
# /content

# %%
# %%shell
# ls
# Out:
# sample_data

# %% [markdown]
# get file name and run

# %%
# %%shell
# echo "file name?"
# read fname
# jupyter nbconvert --to html ${fname}
# Out:
# file name?
# colab_ipynb_to_html.ipynb
# [NbConvertApp] Converting notebook colab_ipynb_to_html.ipynb to html
# [NbConvertApp] Writing 579948 bytes to colab_ipynb_to_html.html
